# %% [markdown]
# <a href="https://colab.research.google.com/github/anku1111/LGM-VIP-JULY2022-INTERNSHIP/blob/main/Task_4_image_pencil_sketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LetsGrowMore (LGMVIP- JULY2022)
#
# Task 4 - Image to pencil Sketch with python
#
# Author Name:- Ankush Ramne

# %%
import cv2

# %%
from google.colab.patches import cv2_imshow

# %%
image=cv2.imread("pexels-pixabay-67857.jpg")
original_image =cv2.resize(image, (700, 500))
cv2_imshow(original_image)
# Out:
# <PIL.Image.Image image mode=RGB size=700x500 at 0x7F2423151090>

# %% [markdown]
# Convert the RBG image to grayscale image

# %%
gray_scale_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_scale_image)
# Out:
# <PIL.Image.Image image mode=L size=700x500 at 0x7F240FF76D90>

# %% [markdown]
# Inverted the grayscale image

# %%
inverted_gray_scale_image = cv2.bitwise_not(gray_scale_image)
cv2_imshow(inverted_gray_scale_image)
# Out:
# <PIL.Image.Image image mode=L size=700x500 at 0x7F240EEF8E50>

# %% [markdown]
# Apply a Guassian Blur

# %%
inverted_blurry_image = cv2.GaussianBlur(inverted_gray_scale_image, (21, 21),sigmaX=0, sigmaY=0)

cv2_imshow(inverted_blurry_image)
# Out:
# <PIL.Image.Image image mode=L size=700x500 at 0x7F240EEF8E50>

# %% [markdown]
# Mixing the gray scale image with inverted blurry image

# %%
def dodgeV2(x, y):
    return cv2.divide(x, 255 - y, scale=256)

# %%
final_pencil_sketch_image = dodgeV2(gray_scale_image,inverted_blurry_image)

cv2_imshow(final_pencil_sketch_image )
# Out:
# <PIL.Image.Image image mode=L size=700x500 at 0x7F240EEF81D0>

# %% [markdown]
# Original image and pencil sketch image

# %%
cv2_imshow(original_image)

cv2_imshow(final_pencil_sketch_image)
# Out:
# <PIL.Image.Image image mode=RGB size=700x500 at 0x7F240EF03C90>
# <PIL.Image.Image image mode=L size=700x500 at 0x7F240EF03E10>
